# %% [markdown]
# # file coco128.yaml

# %% [markdown]
# {
# train: /content/train  # train images (relative to 'path') 128 images
# val: /content/valid  # val images (relative to 'path') 128 images
# test:  # test images (optional)
#
# # Classes
# nc: 4  # number of classes
# names: ['person', 'hardhat', 'vest', 'boot']  # class names
#
#
# # Download script/URL (optional)
# download: https://ultralytics.com/assets/coco128.zip
# }

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12824, done.
# remote: Total 12824 (delta 0), reused 0 (delta 0), pack-reused 12824
# Receiving objects: 100% (12824/12824), 11.81 MiB | 8.64 MiB/s, done.
# Resolving deltas: 100% (8913/8913), done.

# %%
# !mkdir dataset

# %%
# !unzip '/content/drive/MyDrive/PPE Detection/DATASET/data-train-val/test.v1-data-7-4.yolov5pytorch.zip' -d '/content/dataset'

# %%
# !curl -L "https://app.roboflow.com/ds/cvwF09txTh?key=PJCW5JF2AK" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/yolov5/data/coco128.yaml --weights /content/yolov5/yolov5s.pt
# Out:
# train: weights=/content/yolov5/yolov5s.pt, cfg=, data=/content/yolov5/data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-132-g014acde torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ### zip file

# %%
# !zip -r /content/_50_epoch.zip /content/yolov5/runs/train/exp2

# %%
from google.colab import files
files.download("/content/_50_epoch.zip")
